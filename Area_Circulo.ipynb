# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math
a=48.0
control=0
datosX=[]
datosY=[]
radio=0.0
b=34.0
m=123456789.0
k=6.0
Xn=0.0
delta=0.0
rando_x=0.0
rando_y=0.0
gerX=0.0
gerY=0.0
x=0.0
y=0.0
i=0.0
limite=0.0

def congruencialMixto(entrada):
    Xn = ((a*entrada)+b)%m
    return Xn

def congruencialMixtoXn(entrada):
    Xn = ((a*entrada)+b)%m
    return Xn

def convertir(numero):
    val=((2*k)*numero)-k
    return val

x0 = input("Ingrese el valor de la semilla: \n")
limite = input ("Ingrese el numero de valores aleatorios a generar: \n")+0.0
radio = input("Ingrese el radio del circulo: \n")+0.0
rando_x=congruencialMixto(x0)
gerX=congruencialMixtoXn(x0)
while i<limite:
    rando_y=congruencialMixto(gerX)/m
    gerY=congruencialMixtoXn(gerX)
    rando_x=congruencialMixto(gerY)/m
    gerX=congruencialMixtoXn(gerY)
    x=convertir(rando_x)
    y=convertir(rando_y)
    datosX.append(x)
    datosY.append(y)
    i+=1
    valor=rando_x**2+rando_y**2
    if (valor**2)<=radio:
            delta+=((1/limite)*((2*radio)**2))
    plt.ion()
    ax=plt.gca()
    if valor<=(radio**2):
        ax.plot(datosX[control],datosY[control],"b*")
    else:
        ax.plot(datosX[control],datosY[control],"r*")
    plt.draw()
    control+=1

print "Este es el radio generado: "+str(delta)+",y el  radio teorico es: "+str(math.pi*(radio**2))
# Out:
# Bad key "axes.spines.right" on line 210 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.linewidth" on line 321 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "contour.corner_mask" on line 306 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.vertical" on line 339 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.meanprops.color" on line 327 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.bootstrap" on line 312 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "ytick.minor.visible" on line 230 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.capprops.linestyle" on line 317 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "legend.facecolor" on line 266 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.grid.axis" on line 173 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.patchartist" on line 334 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\__init__.py:1039: UserWarning: Bad val "None" on line #264
# 	"legend.framealpha    : None    # opacity of of legend frame
# "
# 	in file "C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle"
# 	Key legend.framealpha: Could not convert "None" to float
#   (val, error_details, msg))
#
# Bad key "boxplot.meanline" on line 326 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.color" on line 319 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.spines.left" on line 209 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.whiskerprops.linestyle" on line 341 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.capprops.color" on line 316 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.medianprops.linestyle" on line 331 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.markeredgecolor" on line 323 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.spines.top" on line 211 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "legend.edgecolor" on line 267 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.spines.bottom" on line 208 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 201 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.whiskerprops.linewidth" on line 342 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.medianprops.linewidth" on line 332 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.showmeans" on line 338 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.meanprops.linestyle" on line 328 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.capprops.linewidth" on line 318 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.boxprops.linewidth" on line 315 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "animation.html" on line 492 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.showcaps" on line 336 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.meanprops.linewidth" on line 329 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "figure.titlesize" on line 273 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "xtick.minor.visible" on line 219 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.boxprops.color" on line 313 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.markerfacecolor" on line 324 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.notch" on line 333 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.boxprops.linestyle" on line 314 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "figure.titleweight" on line 274 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "markers.fillstyle" on line 20 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.labelpad" on line 177 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.marker" on line 322 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.medianprops.color" on line 330 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.showfliers" on line 337 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.markersize" on line 325 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.whiskerprops.color" on line 340 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.linestyle" on line 320 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.whiskers" on line 343 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "errorbar.capsize" on line 309 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "image.composite_image" on line 302 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.showbox" on line 335 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-bright.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-colorblind.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-dark-palette.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-deep.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-muted.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "axes.prop_cycle" on line 2 in
# C:\Users\barbara\Anaconda2\lib\site-packages\matplotlib\mpl-data\stylelib\seaborn-pastel.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
