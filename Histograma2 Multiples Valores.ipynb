# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random

def generadorNumeros(x0, a, b, mod):
    semilla = 7
    print "Parametros ingresados: "
    print "a = "+str(a)+" b = "+str(b)+" modulo = "+str(mod)
    XnAnterior = 0
    randomList = []
    
    print " Numeros Aleatoriso: "
    
    for i in range(x0):
        Xn = float((a*XnAnterior + b)% mod)
        XnAnterior = Xn
        random = float(Xn/mod)
        randomList.append(random)
    Histograma(randomList,a,b,mod)

def Histograma(randomList,a,b,mod):

    plt.hist(randomList)
    Tt= plt.title("Histograma: "+"a = "+str(a)+" b = "+str(b)+ " modulo = "+str(mod), loc='left', fontsize=14, color='red')
    T = plt.xlabel('Valores entre 0 & 1', fontsize=14, color='red')
    F = plt.ylabel('Frecuencia', fontsize=14, color='red')
    fig = plt.gcf()
    plt.grid(True)
    plt.show()

def main():
    generadorNumeros(6,22,43,16) 
    generadorNumeros(1000,22,55,50)
    generadorNumeros(2000,150,250,70)
    generadorNumeros(3000,550,630,120)
    generadorNumeros(4000,780,670,230)
    
main()
# Out:
# Parametros ingresados:
# a = 22 b = 43 modulo = 16
#  Numeros Aleatoriso:
# Parametros ingresados:
# a = 22 b = 55 modulo = 50
#  Numeros Aleatoriso:
# Parametros ingresados:
# a = 150 b = 250 modulo = 70
#  Numeros Aleatoriso:
# Parametros ingresados:
# a = 550 b = 630 modulo = 120
#  Numeros Aleatoriso:
# Parametros ingresados:
# a = 780 b = 670 modulo = 230
#  Numeros Aleatoriso:
